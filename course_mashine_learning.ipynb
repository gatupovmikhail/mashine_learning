# %%
# импорт библиотек
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

def filtr(data,dataC,keys):
    for key in keys:
        i = 1
        for el in data[key]:
            try:
                t = np.float64(el)
            except ValueError:
                if i in dataC.index:
                    dataC.drop(i,inplace=True)
                wr.append(el)
                i+=1
                continue
            if pd.isnull(el):
                if i in dataC.index:
                    dataC.drop(i,inplace=True)
            i+=1

# %%
data = pd.read_csv('train.csv',index_col='Id')
dataC = pd.read_csv('train.csv',index_col='Id')
test = pd.read_csv('test.csv',index_col='Id')
testC = pd.read_csv('test.csv',index_col='Id')
wr = []

filtr(data,dataC,['LotArea','LotFrontage','SalePrice'])
#filtr(test,testC,['LotArea','LotFrontage'])
#testC = test[['LotArea','LotFrontage']] !!!!NOOOO
#testC = test[['LotArea','LotFrontage']].copy()
#print(testC)
testC.drop(testC[pd.isnull(testC)].index,inplace=True)
print(wr)

reg = LinearRegression()
reg.fit(dataC[['LotArea','LotFrontage']],dataC['SalePrice'])
print( reg.coef_, reg.intercept_)
prediction_train = reg.predict(dataC[['LotArea','LotFrontage']])
prediction_test = reg.predict(testC[['LotArea','LotFrontage']])
print(mean_squared_error(y_pred=prediction_train, y_true = dataC['SalePrice']))
print(r2_score(y_pred=prediction_train, y_true = dataC['SalePrice']))
#prediction_test = reg2.predict(test[['x1', 'x2']])
#Neighborhood	CollgCr  LotFrontage	65.0
#LotArea	8450
# Out:
#       LotArea  LotFrontage
# Id
# 1461    11622         80.0
# 1462    14267         81.0
# 1463    13830         74.0
# 1464     9978         78.0
# 1465     5005         43.0
# 1466    10000         75.0
# 1467     7980          NaN
# 1468     8402         63.0
# 1469    10176         85.0
# 1470     8400         70.0
# 1471     5858         26.0
# 1472     1680         21.0
# 1473     1680         21.0
# 1474     2280         24.0
# 1475     2280         24.0
# 1476    12858        102.0
# 1477    12883         94.0
# 1478    11520         90.0
# 1479    14122         79.0
# 1480    14300        110.0
# 1481    13650        105.0
# 1482     7132         41.0
# 1483    18494        100.0
# 1484     3203         43.0
# 1485    13300         67.0
# 1486     8577         63.0
# 1487    17433         60.0
# 1488     8987         73.0
# 1489     9215         92.0
# 1490    10440         84.0
# ...       ...          ...
# 2890     7030         50.0
# 2891     9060         75.0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression
data = pd.read_csv('titanic.csv', index_col='PassengerId')
male = 0
female = 0
surv = 0
pclass = 0
for i in range(1,len(data.index)):
    if data['Sex'][i] == 'male':
        male+=1
    if data['Sex'][i] == 'female':
        female+=1
    if data['Survived'][i] == 1:
        surv+=1
    if data['Pclass'][i] == 1:
        pclass+=1
print('{} {}'.format(male,female)) # 576 314
print(str(surv/len(data.index))) # 38
print(str(pclass/len(data.index)))
data.head()

data.plot(x='Age', y='Fare', style='o');
data.describe()

#data.keys()
#data.shape # строки + столбцы
#len(data.index) # кол-во строк
# data['Pclass']
#data['Pclass'].value_counts()
# Out:
# 576 314
# 0.3838383838383838
# 0.24242424242424243
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# print(data.shape)
# for el in data.keys():
#     print('{}\t{}'.format(el,data[el][1]))
price = data['SalePrice'][:]
plt.subplots(figsize=(20,10))
plt.scatter(np.log(x),np.log(price))
plt.xlabel(prop1)
plt.ylabel('Price')

# %%
def fun(sp):
    sp.drop(0,inplace=True)
sp=pd.DataFrame({'w':[1,2],'y':[3,5]})
fun(sp)
print(sp)
# Out:
#    w  y
# 1  2  5

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import KFold
def rem_ind(array,col):
    indexes = {i:j for (i,j) in zip(array[col][abs(array[col])>2].index,array[col][abs(array[col])>2])}
    return indexes
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
pd.options.display.max_columns = 200
total_NaN = train.isna().sum()
drop_column = total_NaN[total_NaN>train.shape[0]/4]
for drop in drop_column.index:
    del train[drop]
    del test[drop]
#print(test.head())
#test['GarageArea'].value_counts()
train['GarageArea']=train['GarageArea'].fillna(1)
scaler = StandardScaler()
train['GarageArea_scal'] = scaler.fit_transform(train[['GarageArea']])
indexes = {i:j for (i,j) in zip(train['GarageArea_scal'][abs(train['GarageArea_scal'])>2].index,train['GarageArea_scal'][abs(train['GarageArea_scal'])>2])}
#train.drop(indexes,inplace=True)
scaler2=MinMaxScaler()
train['SalePrice_scal'] = scaler2.fit_transform(train[['SalePrice']])
#plt.scatter(train['GarageArea_scal'],train['SalePrice_scal'])
train['LotArea_scal']=scaler.fit_transform(train[['LotArea']])
indexes = rem_ind(train,'LotArea_scal')
#train.drop(indexes,inplace=True)
#plt.scatter(train['LotArea_scal'],train['SalePrice_scal'])
train['YearBuilt_scal'] = scaler2.fit_transform(train[['YearBuilt']])
plt.scatter(train['YearBuilt_scal'],train['SalePrice_scal'])
features = ['GarageArea_scal','LotArea_scal','YearBuilt_scal']
kf = KFold(n_splits=5)

#print(train.loc[[1,2,3],features])
model = LinearRegression()
rmse_list = []
r2_list = []
for train_ind,test_ind in kf.split(train):
    x_train,x_test = train.loc[train_ind,features], train.loc[test_ind,features]
    y_train,y_test = train.loc[train_ind,['SalePrice_scal']], train.loc[test_ind,['SalePrice_scal']]
    model.fit(x_train,y_train)
    #print( model.coef_, model.intercept_)
    predict = model.predict(x_test)
    rmse = np.sqrt(mean_squared_error(predict,y_test))
    rmse_list.append(rmse)
    r2 = r2_score(predict,y_test)
    r2_list.append(r2)
prediction = model.predict(test[features])
# print(rmse_list)
# print(r2_list)
output = pd.DataFrame()
output['Id'] = test['Id']
output['SalePrice'] = prediction
# Out:
# [[0.04763042 0.01941133 0.16231141]] [0.08560333]
# [[0.04571133 0.02883285 0.15839653]] [0.08827971]
# [[0.0474336  0.01724652 0.15332267]] [0.09208306]
# [[0.052043   0.01807682 0.14900739]] [0.09780047]
# [[0.05102175 0.01984877 0.15417861]] [0.09139635]
# [0.06994168869830153, 0.08028038785257545, 0.08712706211708811, 0.07366930390281089, 0.0885540212250591]
# [0.14250695580685668, 0.18081181910806166, -0.47404746179681734, 0.006561305370933135, -0.21231182139652582]

# %%
# Препроцессинг с сайта
f.shape # мы увидим информацию о размерности нашего датафрейма 
df.info() # покажет информацию о размерности данных 
          # описание индекса, количество not-a-number элементов 
df.describe() # показывает статистики count,mean, std, min, 25%-50%-75% percentile, max 
df.nunique() # количество уникальных значений для каждого столбца 
feature_names = df.columns.tolist() 
for column in feature_names: 
    print column 
    print df[column].value_counts(dropna=False)

from sklearn.preprocessing import Imputer 
imputer = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 0) 
imputer.fit(features)  
features = imputer.transform(features)

# %% [markdown]
# http://blog.datalytica.ru/2018/04/blog-post.html

# %%
# mas=np.array(train['GarageArea_scal_mean'])
# imputer2 = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 0)
# train['GarageArea_scal_mean'] = imputer2.fit_transform(mas.reshape(-1,1))

# %%
#categorias = list(train['Neighborhood_num'].value_counts().keys())
#one_hot_encoder = OneHotEncoder(categorical_features = categorias)
#train['Neighborhood_2'] = train['Neighborhood'].copy()
# test['Neighborhood_2'] = test['Neighborhood'].copy()
#train2 = list(train['Neighborhood_num'].reshape(-1,1))
#one_hot_encoder.fit(train['Neighborhood_num'])
# train2 = one_hot_encoder.transform(train['Neighborhood_num'])
# train['Neighborhood_num'] = encoder.transform(train['Neighborhood_num'])
# test['Neighborhood_num'] = encoder.transform(test['Neighborhood_num'])
# scaler2 = MinMaxScaler()
# train['Neighborhood_num_scal'] = scaler2.fit_transform(train[['Neighborhood_num']])
# test['Neighborhood_num_scal'] = scaler2.transform(test[['Neighborhood_num']])
# train.head()
#indexes = rem_ind(train,'LotArea_scal')
#train.drop(indexes,inplace=True)

# %% [markdown]
# ## Вопросы:
# * В чем отличие scaler.fit_transform() и scaler.transform()?
# * В модели 1 и модели 2 различаются только форма представления SalePrice, причем логарифмическая шкала оказалась хуже линейного преобразования MinMax. Есть ли признаки, по которым можно понять, когда стоит использовать именно логарифмическую шкалу?
# * Непонятно, какая именно разница между например train[['SalePrice']] и train['SalePrice'].
# * При каких результатах кросс-валидации мы можем сказать, что переобучились?

# %%
# HW2
